# %% [markdown]
# <a href="https://colab.research.google.com/github/daniel-nguyen123/INFO450/blob/main/Lesson6/Lesson6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = ""
print(name)
print(bool(name))
# Out:
# False

# %%
bool(0) #only 0 get assigned false
# Out:
# False

# %%
x = 10    #if statement
if x > 5:
  print("x is greater than 5")
# Out:
# x is greater than 5

# %%
x = 3    #if else statement
if x > 5:
  print("x is greater tha 5")
else:
  print("x is not greater than 5")
# Out:
# x is not greater than 5

# %%
x = 81    #elif statements
if x > 90:
  print("A")
elif x > 80:
  print("B")
elif x > 70:
  print("C")
else:
  print("go to summer school")
# Out:
# B

# %%
age = 25
income = 50000
#want to make sure they are an adult making 40k a year
if age > 18 and income > 40000:
  print("congrats on the loan")
# Out:
# congrats on the loan

# %%
age = 25
income = 50000
#want to make sure they are an adult making 40k a year
if (age > 18 and income > 40000) or income > 4000000:
  print("congrats on the loan")
# Out:
# congrats on the loan

# %%
hours_worked = 40
performance_score = 85
tenure = 2 #years with the company
if (hours_worked >= 40 and performance_score > 80) or tenure >= 2:
  print("promoted")
else:
  print("not")
# Out:
# promoted

# %%
x = 3
y = 4
if x == y:
  print("x and y are the same")
else:
  if x < y:
    print("x is smaller")
  else:
    print("y is smaller")
  print("outside the if statement")
# Out:
# x is smaller

# %%
scores = [80,45,78,96,88]

# %%
if min(scores) > 60:
  print("yall passed")
else:
  print("yall didnt pass")
# Out:
# yall didnt pass
